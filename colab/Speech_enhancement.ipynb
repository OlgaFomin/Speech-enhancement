# %% [markdown]
# Cloning Speech-enhacement git repository

# %%
# !git clone https://github.com/vbelz/Speech-enhancement
# Out:
# Cloning into 'Speech-enhancement'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 158 (delta 28), reused 37 (delta 13), pack-reused 102
# Receiving objects: 100% (158/158), 47.19 MiB | 29.16 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %% [markdown]
# Removing text files from 'data/Train/clean_voice' directory

# %%
from google.colab import drive
from glob import glob
import os

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive'
train_path = root_path + '/data/Train'
clean_voice_path = train_path + '/clean_voice'

print('Removing txt files if exist...')
tfiles = glob(clean_voice_path + '/*.txt')
for tfile in tfiles:
  print('Removing ' + tfile)
  os.remove(tfile)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Removing txt files if exist...

# %% [markdown]
# Create N2C and N2N data

# %%
# !python Speech-enhancement/main.py --mode='data_creation'
# Out:
# 2020-08-19 07:10:46.365908: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2.3.0

# %% [markdown]
# Train N2C model

# %%
# %run Speech-enhancement/main.py --mode='training'
# Out:
# DescribeResult(nobs=819200, minmax=(array([-80.]), array([1.90734863e-06])), mean=array([-41.92728857]), variance=array([191.58213492]), skewness=array([0.0960858]), kurtosis=array([-0.13649537]))
# DescribeResult(nobs=819200, minmax=(array([-60.0111227]), array([78.78753662])), mean=array([9.77409453]), variance=array([177.78616209]), skewness=array([1.18743945]), kurtosis=array([1.22659537]))
# (50, 128, 128)
# (50, 128, 128)
# DescribeResult(nobs=819200, minmax=(array([-0.68]), array([0.92000004])), mean=array([0.08145423]), variance=array([0.07663285]), skewness=array([0.0960858]), kurtosis=array([-0.13649537]))
# DescribeResult(nobs=819200, minmax=(array([-0.80501369]), array([0.88765289])), mean=array([0.04602554]), variance=array([0.02644054]), skewness=array([1.18743945]), kurtosis=array([1.22659537]))
# Model: "functional_9"
# __________________________________________________________________________________________________
# ...

# %%
# !python Speech-enhancement/main.py --mode='training'
# Out:
# 2020-08-19 10:09:30.198819: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2.3.0
# DescribeResult(nobs=819200, minmax=(array([-80.]), array([1.90734863e-06])), mean=array([-41.92728857]), variance=array([191.58213492]), skewness=array([0.0960858]), kurtosis=array([-0.13649537]))
# DescribeResult(nobs=819200, minmax=(array([-60.0111227]), array([78.78753662])), mean=array([9.77409453]), variance=array([177.78616209]), skewness=array([1.18743945]), kurtosis=array([1.22659537]))
# (50, 128, 128)
# (50, 128, 128)
# DescribeResult(nobs=819200, minmax=(array([-0.68]), array([0.92000004])), mean=array([0.08145423]), variance=array([0.07663285]), skewness=array([0.0960858]), kurtosis=array([-0.13649537]))
# DescribeResult(nobs=819200, minmax=(array([-0.80501369]), array([0.88765289])), mean=array([0.04602554]), variance=array([0.02644054]), skewness=array([1.18743945]), kurtosis=array([1.22659537]))
# ...

# %%
# !python Speech-enhancement/main.py --mode='training_n2n'
# Out:
# 2020-08-19 10:13:13.511823: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2.3.0
# DescribeResult(nobs=819200, minmax=(array([-80.]), array([1.90734863e-06])), mean=array([-41.92728857]), variance=array([191.58213492]), skewness=array([0.0960858]), kurtosis=array([-0.13649537]))
# DescribeResult(nobs=819200, minmax=(array([-64.88198471]), array([55.83403778])), mean=array([-3.04666366]), variance=array([50.59506399]), skewness=array([-1.2095074]), kurtosis=array([3.62130058]))
# (50, 128, 128)
# (50, 128, 128)
# DescribeResult(nobs=819200, minmax=(array([-0.68]), array([0.92000004])), mean=array([0.08145423]), variance=array([0.07663285]), skewness=array([0.0960858]), kurtosis=array([-0.13649537]))
# DescribeResult(nobs=819200, minmax=(array([-0.86441445]), array([0.60773217])), mean=array([-0.11032517]), variance=array([0.00752455]), skewness=array([-1.2095074]), kurtosis=array([3.62130058]))
# ...
